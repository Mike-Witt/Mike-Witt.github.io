# %%
# %matplotlib inline
import pylab as pl
import numpy as np

# %% [markdown]
# <h2>
# Let's plot:
# $
# y = \sin(x)
# $
# </h2>
# <p>

# %%
x0 = 0; x1 = 2*np.pi; npts = 61
X = np.linspace(x0, x1, npts)
pl.plot(X, np.sin(X))
foo = pl.xlim(x0, x1)
